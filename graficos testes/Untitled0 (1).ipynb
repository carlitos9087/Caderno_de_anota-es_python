# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


a=pd.DataFrame([[42.98, 46.61],
[43.86, 46.43],
[44.74, 46.82],
[43.42, 46.43],
[45.18, 44.84],
[43.42, 45.98],
[43.42, 46.43],
[42.54, 45.98],
[43.86, 46.43],
[44.30, 46.36],
[43.86, 47.32],
[42.98, 46.61],
[43.42, 45.98]], index=["L. aethiopica", "L. amazonensis", "L. brasiliensis", "L. donovani", "L. enriettii", "L. gerbilli", "L. infantum", "L. major Friendlin", "L. mexicana", "L. panamensis", "L. tarentolae", "L. tropica", "L. turanica"])
fig, ax = plt.subplots(figsize=(8, 5)) #x y

#b=sns.heatmap(a, annot=True, fmt=".2f")

h = sns.heatmap(a, annot=True, fmt=".2f")
h.set(xlabel="", ylabel="")
h.xaxis.tick_top()
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
plt.show()
figure = h.get_figure()

figure.savefig( 'heatmap.png', dpi=400)

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
co = pd.DataFrame(np.array([[36.7, 38.4],
                             [36.4, 39.2],
                             [35.8, 38.6],
                             [36.6, 39.6],
                             [36.2, 39.4],
                             [36.2, 39.4],
                             [36.1, 39.5],
                             [36.0, 39.4],
                             [36.0, 39.5],
                             [36.3, 39.2],
                             [36.3, 39.2],
                             [36.3, 39.5],
                             [36.4, 39.5]]),columns=['Saccharomyces_cerevisiae',	'Human'], index=["L.enriettii","L.braziliensis M2903","L.panamensis","L.tarentolae","L.amazonensis","L.mexicana","L.donovani","L.infantum JPCM5","L.major Friendlin","L.gerbilli","L.turanica","L.aethiopica ","L.tropica"])
sns.heatmap(co, cmap='Blues', vmin=33, vmax=40,  annot=True, annot_kws={"size": 12}, linewidths=1, linecolor='grey');

# %%
# Create a array of marks in different subjects scored by different students 
marks = pd.DataFrame(np.array([[36.7, 38.4],
                 [36.4, 39.2],
                 [35.8, 38.6],
                 [36.6, 39.6],
                 [36.2, 39.4],
                 [36.2, 39.4],
                 [36.1, 39.5],
                 [36.0, 39.4],
                 [36.0, 39.5],
                 [36.3, 39.2],
                 [36.3, 39.2],
                 [36.3, 39.5],
                 [36.4, 39.5]])
# name of students
names=['Saccharomyces_cerevisiae',	'Human']
# name of subjects
subjects=["L.enriettii","L.braziliensis M2903","L.panamensis","L.tarentolae","L.amazonensis","L.mexicana","L.donovani","L.infantum JPCM5","L.major Friendlin","L.gerbilli","L.turanica","L.aethiopica ","L.tropica"]
 
# Setting the labels of x axis.
# set the <a href="https://www.pythonpool.com/matplotlib-xticks/" target="_blank" rel="noreferrer noopener">xticks</a> as student-names
# rotate the labels by 90 degree to fit the names
plt.xticks(ticks=np.arange(len(names)),labels=names,rotation=90)
# Setting the labels of y axis.
# set the xticks as subject-names
plt.yticks(ticks=np.arange(len(subjects)),labels=subjects)
# use the imshow function to generate a heatmap
# cmap parameter gives color to the graph
# setting the interpolation will lead to different types of graphs
sns.heatmap(, cmap='Blues' annot=True, annot_kws={"size": 12});
l= plt.imshow(marks, cmap='Blues',interpolation="nearest", vmin=33, vmax=40)
plt.colorbar(l)

# %%
# Create a array of marks in different subjects scored by different students 
marks = np.array([  [50, 74, 40, 59, 90, 98],
                    [72, 85, 64, 33, 47, 87],
                    [52, 97, 44, 73, 17, 56],
                    [69, 45, 89, 79, 70, 48],
                    [87, 65, 56, 86, 72, 68],
                    [90, 29, 78, 66, 50, 32]])
# name of students
names=['Sumit','Ashu','Sonu','Kajal','Kavita','Naman']
# name of subjects
subjects=['Maths','Hindi','English','Social Studies','Science','Computer Science']
 
# Setting the labels of x axis.
# set the <a href="https://www.pythonpool.com/matplotlib-xticks/" target="_blank" rel="noreferrer noopener">xticks</a> as student-names
# rotate the labels by 90 degree to fit the names
plt.xticks(ticks=np.arange(len(names)),labels=names,rotation=45)
# Setting the labels of y axis.
# set the xticks as subject-names
plt.yticks(ticks=np.arange(len(subjects)),labels=subjects)
# use the imshow function to generate a heatmap
# cmap parameter gives color to the graph
# setting the interpolation will lead to different types of graphs

hm=plt.imshow(marks, cmap='Blues',interpolation="nearest");
plt.colorbar(hm);

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
#!usr/bin/python3

import pandas as pd
import seaborn as sns; sns.set_theme()

expressao = pd.pd.read_table('nome.tsv', index_col=0)

ax = sns.heatmap(expressao, vmin=0, vmax=1, cbar=True, xticklabels= True, yticklabels=True)


ax.Set_yticklabels(ax.get_yticklabels(), rotation = 0, fontsize = 5)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90, fontsize = 5)


figure = ax.get_figure()

figure.savefig( 'heatmap.png', dpi=400)

# %%
# library
import seaborn as sns
import pandas as pd
import numpy as np

# Create a dataset
df = pd.DataFrame(np.array([[36.7, 38.4],
                 [36.4, 39.2],
                 [35.8, 38.6],
                 [36.6, 39.6],
                 [36.2, 39.4],
                 [36.2, 39.4],
                 [36.1, 39.5],
                 [36.0, 39.4],
                 [36.0, 39.5],
                 [36.3, 39.2],
                 [36.3, 39.2],
                 [36.3, 39.5],
                 [36.4, 39.5]]), columns=["a","b"])


# Default heatmap
df
p1 = sns.heatmap(df, annot=df)

# %%
# library
import seaborn as sns
import pandas as pd
import numpy as np


# Create a dataset
df = pd.DataFrame(np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                            [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                            [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                            [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                            [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                            [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                            [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]]), columns=["a","b","c","d","e","f","g"])

# Default heatmap 
p1 = sns.heatmap(df, cmap="coolwarm", annot=True, annot_kws={"size": 7}, linewidths=2, linecolor='yellow',yticklabels=True, xticklabels=2, cbar=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
# this is our data
x=[[1.,337.,118.,4.,4.5 ,4.5 ,9.65,1.,0.92],
   [2.,324.,107.,4.,4.,4.5 ,8.87,1.,0.76],
   [3.,316.,104.,3.,3.,3.5 ,8.,1.,0.72],
[4.,322.,110.,3.,3.5 ,2.5 ,8.67,1.,0.8 ],
[5.,314.,103.,2.,2.,3.,8.21,0.,0.65],
[6.,330.,115.,5.,4.5 ,3.,9.34,1.,0.9 ],
[7.,321.,109.,3.,3.,4.,8.2 ,1.,0.75],
[8.,308.,101.,2.,3.,4.,7.9 ,0.,0.68],
[9.,302.,102.,1.,2.,1.5 ,8.,0.,0.5 ],
[ 10.,323.,108.,3.,3.5 ,3.,8.6 ,0.,0.45],
[ 11.,325.,106.,3.,3.5 ,4.,8.4 ,1.,0.52],[ 12.,327.,111.,4.,4.,4.5 ,9.,1.,0.84],
[ 13.,328.,112.,4.,4.,4.5 ,9.1 ,1.,0.78],[ 14.,307.,109.,3.,4.,3.,8.,1.,0.62],[ 15.,311.,104.,3.,3.5 ,2.,8.2 ,1.,0.61],
[ 16.,314.,105.,3.,3.5 ,2.5 ,8.3 ,0.,0.54],[ 17.,317.,107.,3.,4.,3.,8.7 ,0.,0.66],[ 18.,319.,106.,3.,4.,3.,8.,1.,0.65],
[ 19.,318.,110.,3.,4.,3.,8.8 ,0.,0.63],[ 20.,303.,102.,3.,3.5 ,3.,8.5 ,0.,0.62],[ 21.,312.,107.,3.,3.,2.,7.9 ,1.,0.64],
[ 22.,325.,114.,4.,3.,2.,8.4 ,0.,0.7 ],[ 23.,328.,116.,5.,5.,5.,9.5 ,1.,0.94],[ 24.,334.,119.,5.,5.,4.5 ,9.7 ,1.,0.95],
[ 25.,336.,119.,5.,4.,3.5 ,9.8 ,1.,0.97],[ 26.,340.,120.,5.,4.5 ,4.5 ,9.6 ,1.,0.94],
[ 27.,322.,109.,5.,4.5 ,3.5 ,8.8 ,0.,0.76],[ 28.,298.,98.,2.,1.5 ,2.5 ,7.5 ,1.,0.44],[ 29.,295.,93.,1.,2.,2.,7.2 ,0.,0.46],
[ 30.,310.,99.,2.,1.5 ,2.,7.3 ,0.,0.54],[ 31.,300.,97.,2.,3.,3.,8.1 ,1.,0.65],
[ 32.,327.,103.,3.,4.,4.,8.3 ,1.,0.74], [ 33.,338.,118.,4.,3.,4.5 ,9.4 ,1.,0.91], [ 34.,340.,114.,5.,4.,4.,9.6 ,1.,0.9 ],
[ 35.,331.,112.,5.,4.,5.,9.8 ,1.,0.94], [ 36.,320.,110.,5.,5.,5.,9.2 ,1.,0.88],
[ 37.,299.,106.,2.,4.,4.,8.4 ,0.,0.64], [ 38.,300.,105.,1.,1.,2.,7.8 ,0.,0.58], [ 39.,304.,105.,1.,3.,1.5 ,7.5 ,0.,0.52],
[ 40.,307.,108.,2.,4.,3.5 ,7.7 ,0.,0.48], [ 41.,308.,110.,3.,3.5 ,3.,8.,1.,0.46], [ 42.,316.,105.,2.,2.5 ,2.5 ,8.2 ,1.,0.49],
[ 43.,313.,107.,2.,2.5 ,2.,8.5 ,1.,0.53], [ 44.,332.,117.,4.,4.5 ,4.,9.1 ,0.,0.87], [ 45.,326.,113.,5.,4.5 ,4.,9.4 ,1.,0.91],
[ 46.,322.,110.,5.,5.,4.,9.1 ,1.,0.88], [ 47.,329.,114.,5.,4.,5.,9.3 ,1.,0.86], [ 48.,339.,119.,5.,4.5 ,4.,9.7 ,0.,0.89],
[ 49.,321.,110.,3.,3.5 ,5.,8.85,1.,0.82], [ 50.,327.,111.,4.,3.,4.,8.4 ,1.,0.78]]
 
# column name
ab=['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
       'LOR ', 'CGPA', 'Research', 'Chance of Admit ']
a=[1,2,3,4]
# create a dataframe with the above values and column names 
dataset=pd.DataFrame(data=x,columns=ab,)

# to find the correlation, use corr() method on the dataset
corr=dataset.corr()
 


 
plt.xticks(range(len(ab)),ab,rotation=90)
plt.yticks(range(len(a)),a)
d=plt.imshow(corr, cmap='hot',interpolation="nearest")
plt.colorbar(d);

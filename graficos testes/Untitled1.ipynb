# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

a=pd.DataFrame([[42.98, 46.61],
[43.86, 46.43],
[44.74, 46.82],
[43.42, 46.43],
[45.18, 44.84],
[43.42, 45.98],
[43.42, 46.43],
[42.54, 45.98],
[43.86, 46.43],
[44.30, 46.36],
[43.86, 47.32],
[42.98, 46.61],
[43.42, 45.98]], index=[u'${L. aethiopica}$', u'${L. amazonensis}$', u'${L. braziliensis}$', 
                        u'${L. donovani}$', u'${L. enriettii}$', u'${L. gerbilli}$', u'${L. infantum}$',
                        u'${L. major}$', u'${L. mexicana}$', u'${L. panamensis}$', u'${L. tarentolae}$',
                        u'${L. tropica}$', u'${L. turanica}$'], columns=[u'${S. cerevisiae}$',	'Human'])
fig, ax = plt.subplots(figsize=(4, 6)) #x y

h = sns.heatmap(a, annot=True, fmt=".2f", cmap="crest", cbar_kws={'shrink': 0.8})
plt.title(u"GNAT", fontsize=15)
#h.set(xlabel="fdsf", ylabel="")
h.xaxis.tick_top()
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
plt.savefig('heatmap.tif', dpi=600, format='tif', bbox_inches='tight', pad_inches=0.2, bbox=None, pad=None, dashes=None, loc='upper left', rot=0, vmax='I', vmin='I', hmax='I', hmin='I')
#figure = h.get_figure()
#figure.savefig( 'heatmap.png', dpi=400)

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

b=pd.DataFrame([[55.73,60.42],
[55.73,59.90],
[54.69,59.38],
[55.73,60.94],
[54.69,58.85],
[55.21,59.38],
[55.73,60.94],
[55.21,59.38],
[55.73,59.90],
[54.69,59.38],
[55.21,59.90],
[55.73,60.42],
[55.21,59.38]], index=[u'${L. aethiopica}$', u'${L. amazonensis}$', u'${L. braziliensis}$', 
                        u'${L. donovani}$', u'${L. enriettii}$', u'${L. gerbilli}$', u'${L. infantum}$',
                        u'${L. major}$', u'${L. mexicana}$', u'${L. panamensis}$', u'${L. tarentolae}$',
                        u'${L. tropica}$', u'${L. turanica}$'], columns=[u'${S. cerevisiae}$',	'Human'])
fig, ax = plt.subplots(figsize=(4, 6)) #x y
h = sns.heatmap(b, annot=True, fmt=".2f", cmap="Greens", vmin=52, vmax=61,cbar_kws={'shrink': 0.8})
plt.title('Helicase', fontsize=15)
#h.set(xlabel="fdsf", ylabel="")
h.xaxis.tick_top()
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')

plt.savefig('heatmap2.tif', dpi=600, format='tif', bbox_inches='tight', pad_inches=0.2, bbox=None, pad=None, dashes=None, loc='upper left', rot=0, vmax='I', vmin='I', hmax='I', hmin='I')
#figure = h.get_figure()
#figure.savefig( 'heatmap.png', dpi=400)

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


c = pd.DataFrame([[36.3,39.5],
[36.2,39.4],
[36.4,39.2],
[36.1,39.5],
[36.7,38.4],
[36.3,39.2],
[36.0,39.4],
[36.0,39.5],
[36.2,39.4],
[35.8,38.6],
[36.6,39.6],
[36.4,39.5],
[36.3,39.2]], index=[u'${L. aethiopica}$', u'${L. amazonensis}$', u'${L. braziliensis}$', 
                        u'${L. donovani}$', u'${L. enriettii}$', u'${L. gerbilli}$', u'${L. infantum}$',
                        u'${L. major}$', u'${L. mexicana}$', u'${L. panamensis}$', u'${L. tarentolae}$',
                        u'${L. tropica}$', u'${L. turanica}$'], columns=[u'${S. cerevisiae}$',	'Human'])
fig, ax = plt.subplots(figsize=(4, 6)) #x y
#b=sns.heatmap(a, annot=True, fmt=".2f")
h = sns.heatmap(c, annot=True, fmt=".2f", vmin=33, vmax=40,cmap="ocean",cbar_kws={'shrink': 0.8})#####################
plt.title('NAT10',fontsize=15)
h.xaxis.tick_top()
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
plt.savefig('heatmap3.tif', dpi=600, format='tif', bbox_inches='tight', pad_inches=0.2, bbox=None, pad=None, dashes=None, loc='upper left', rot=0, vmax='I', vmin='I', hmax='I', hmin='I')

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


d = pd.DataFrame(np.array([[29.01, 24.68],
[27.04, 25.53],
[29.37, 26.97],
[30.57, 26.17],
[30.82, 24.5],
[29.63, 24.68],
[30.57, 26.17],
[29.3, 25.5],
[28.57, 24.53],
[29.37, 26.97],
[30.91, 24.84],
[28.14, 24.05],
[30.06, 24.52]]), index=[u'${L. aethiopica}$', u'${L. amazonensis}$', u'${L. braziliensis}$', 
                        u'${L. donovani}$', u'${L. enriettii}$', u'${L. gerbilli}$', u'${L. infantum}$',
                        u'${L. major}$', u'${L. mexicana}$', u'${L. panamensis}$', u'${L. tarentolae}$',
                        u'${L. tropica}$', u'${L. turanica}$'], columns=[u'${S. cerevisiae}$',	'Human'])
fig, ax = plt.subplots(figsize=(4, 6)) #x y


h = sns.heatmap(d, annot=True, fmt=".2f", vmin=22, vmax=32,cmap="OrRd",cbar_kws={'shrink': 0.8})#####################
plt.title('tRNA',fontsize=15)
h.xaxis.tick_top()
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
plt.savefig('heatmap4.tif', dpi=600, format='tif', bbox_inches='tight', pad_inches=0.2, bbox=None, pad=None, dashes=None, loc='upper left', rot=0, vmax='I', vmin='I', hmax='I', hmin='I')

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


e = pd.DataFrame(np.array([[46.11, 54.4],
[45.6, 53.37],
[44.56, 53.89],
[45.6, 53.37],
[46.11, 54.4],
[45.6, 53.89],
[45.08, 52.85],
[46.11, 54.4],
[45.6, 53.37],
[44.56, 53.89],
[44.56, 53.89],
[46.11, 54.4],
[45.6, 53.89]]), index=[u'${L. aethiopica}$', u'${L. amazonensis}$', u'${L. braziliensis}$', 
                        u'${L. donovani}$', u'${L. enriettii}$', u'${L. gerbilli}$', u'${L. infantum}$',
                        u'${L. major}$', u'${L. mexicana}$', u'${L. panamensis}$', u'${L. tarentolae}$',
                        u'${L. tropica}$', u'${L. turanica}$'], columns=[u'${S. cerevisiae}$',	'Human'])

fig, ax = plt.subplots(figsize=(4, 6)) #x y
h = sns.heatmap(e, annot=True, fmt=".2f", vmin=40, vmax=55,cmap="PuRd", cbar_kws={'shrink': 0.8})#####################
plt.title('Tmca')
h.xaxis.tick_top()
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
plt.savefig('heatmap5.tif', dpi=600, format='tif', bbox_inches='tight', pad_inches=0.2, bbox=None, pad=None, dashes=None, loc='upper left', rot=0, vmax='I', vmin='I', hmax='I', hmin='I')
# Out:
#                      ${S. cerevisiae}$  Human
# ${L. aethiopica}$                46.11  54.40
# ${L. amazonensis}$               45.60  53.37
# ${L. braziliensis}$              44.56  53.89
# ${L. donovani}$                  45.60  53.37
# ${L. enriettii}$                 46.11  54.40
# ${L. gerbilli}$                  45.60  53.89
# ${L. infantum}$                  45.08  52.85
# ${L. major}$                     46.11  54.40
# ${L. mexicana}$                  45.60  53.37
# ${L. panamensis}$                44.56  53.89
# ${L. tarentolae}$                44.56  53.89
# ${L. tropica}$                   46.11  54.40
# ${L. turanica}$                  45.60  53.89

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


e = pd.DataFrame(np.array([[46.11, 54.4],
[45.6, 53.37],
[44.56, 53.89],
[45.6, 53.37],
[46.11, 54.4],
[45.6, 53.89],
[45.08, 52.85],
[46.11, 54.4],
[45.6, 53.37],
[44.56, 53.89],
[44.56, 53.89],
[46.11, 54.4],
[45.6, 53.89]]), index=[u'${L. aethiopica}$', u'${L. amazonensis}$', u'${L. braziliensis}$', 
                        u'${L. donovani}$', u'${L. enriettii}$', u'${L. gerbilli}$', u'${L. infantum}$',
                        u'${L. major}$', u'${L. mexicana}$', u'${L. panamensis}$', u'${L. tarentolae}$',
                        u'${L. tropica}$', u'${L. turanica}$'], columns=[u'${S. cerevisiae}$',	'Human'])


fig, ax = plt.subplots(figsize=(4, 6)) #x y
h = sns.heatmap(e, annot=True, fmt=".2f", vmin=40, vmax=55,cmap="PuRd", cbar_kws={'shrink': 0.8})#####################
plt.title('Tmca')
h.xaxis.tick_top()
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, horizontalalignment='right')
plt.savefig('heatmap5.tif', dpi=600, format='tif', bbox_inches='tight', pad_inches=0.2, bbox=None, pad=None, dashes=None, loc='upper left', rot=0, vmax='I', vmin='I', hmax='I', hmin='I')
# Out:
#                      ${S. cerevisiae}$  Human
# ${L. aethiopica}$                46.11  54.40
# ${L. amazonensis}$               45.60  53.37
# ${L. braziliensis}$              44.56  53.89
# ${L. donovani}$                  45.60  53.37
# ${L. enriettii}$                 46.11  54.40
# ${L. gerbilli}$                  45.60  53.89
# ${L. infantum}$                  45.08  52.85
# ${L. major}$                     46.11  54.40
# ${L. mexicana}$                  45.60  53.37
# ${L. panamensis}$                44.56  53.89
# ${L. tarentolae}$                44.56  53.89
# ${L. tropica}$                   46.11  54.40
# ${L. turanica}$                  45.60  53.89

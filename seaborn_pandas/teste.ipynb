# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', sep=',')# caso fosse outro separador bastaria substituir no sep
df.shape
df.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst  Unnamed: 32
# ...

# %%
cols=['diagnosis','radius_mean', 'texture_mean', 'smoothness_mean']

# %%
#df.iloc[linhas, colunas]
df.iloc[1:11,1:5]
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean
# 1          M        20.57         17.77          132.90
# 2          M        19.69         21.25          130.00
# 3          M        11.42         20.38           77.58
# 4          M        20.29         14.34          135.10
# 5          M        12.45         15.70           82.57
# 6          M        18.25         19.98          119.60
# 7          M        13.71         20.83           90.20
# 8          M        13.00         21.82           87.50
# 9          M        12.46         24.04           83.97
# 10         M        16.02         23.24          102.70

# %%
df.set_index('id', inplace=True)

# %%
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#df.loc[linhas, colunas]
df.loc[:,'diagnosis':'compactness_mean'].head(3)
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38           122.8     1001.0
# 842517           M        20.57         17.77           132.9     1326.0
# 84300903         M        19.69         21.25           130.0     1203.0
#
#           smoothness_mean  compactness_mean
# id
# 842302            0.11840           0.27760
# 842517            0.08474           0.07864
# 84300903          0.10960           0.15990

# %%
df.loc[842302:84358402,'diagnosis':'compactness_mean']
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean
# id
# 842302            0.11840           0.27760
# 842517            0.08474           0.07864
# 84300903          0.10960           0.15990
# 84348301          0.14250           0.28390
# 84358402          0.10030           0.13280

# %%
df.loc[842302:84358402,['diagnosis','compactness_mean']]
# Out:
#          diagnosis  compactness_mean
# id
# 842302           M           0.27760
# 842517           M           0.07864
# 84300903         M           0.15990
# 84348301         M           0.28390
# 84358402         M           0.13280

# %%
df.loc[842302:84358402,cols]
# Out:
#          diagnosis  radius_mean  texture_mean  smoothness_mean
# id
# 842302           M        17.99         10.38          0.11840
# 842517           M        20.57         17.77          0.08474
# 84300903         M        19.69         21.25          0.10960
# 84348301         M        11.42         20.38          0.14250
# 84358402         M        20.29         14.34          0.10030

# %%
#df.mean() #media de todas as colunas
#df.mean(axis=1) #media dos indices linhas
#df.std(axis=0) #desvio padrão
#df.max(axis=0) #maximo
#df.min(axis=0) #minimo
#df.sum(axis=0) #soma de todas
#df.median() #mediana
#df.quantile(q=.5) #mediana quantial
#df.corr() #correlação
#df.cov() #covariancia
#df.describe() #descrição geral
#df.describe().T #descrição transposta

# %%
df[cols].describe()
# Out:
#        radius_mean  texture_mean  smoothness_mean
# count   569.000000    569.000000       569.000000
# mean     14.127292     19.289649         0.096360
# std       3.524049      4.301036         0.014064
# min       6.981000      9.710000         0.052630
# 25%      11.700000     16.170000         0.086370
# 50%      13.370000     18.840000         0.095870
# 75%      15.780000     21.800000         0.105300
# max      28.110000     39.280000         0.163400

# %%
def c_radius(value):
    return 2*value

# %%
df.apply(c_radius)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      1684604        MM        35.98         20.76          245.60
# 1      1685034        MM        41.14         35.54          265.80
# 2    168601806        MM        39.38         42.50          260.00
# 3    168696602        MM        22.84         40.76          155.16
# 4    168716804        MM        40.58         28.68          270.20
# ..         ...       ...          ...           ...             ...
# 564    1852848        MM        43.12         44.78          284.00
# 565    1853364        MM        40.26         56.50          262.40
# 566    1853908        MM        33.20         56.16          216.60
# 567    1854482        MM        41.20         58.66          280.20
# 568     185502        BB        15.52         49.08           95.84
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       2002.0          0.23680           0.55520         0.60020
# ...

# %%
#df.drop(columns=['Unnamed: 32'], inplace=True)
df.drop('Unnamed: 32', axis=1, inplace=True)

# %%
df['difRadius_mean_wort'] = df['radius_mean'] - df['radius_worst']
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df['difRadius_mean_wort_percentual'] = 100*(df['radius_mean'] - df['radius_worst'])/df['radius_worst']
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df['radius_mean'].median()
# Out:
# 13.37

# %%
df['radius_mean']>=13.37
# Out:
# id
# 842302       True
# 842517       True
# 84300903     True
# 84348301    False
# 84358402     True
#             ...
# 926424       True
# 926682       True
# 926954       True
# 927241       True
# 92751       False
# Name: radius_mean, Length: 569, dtype: bool

# %%
df[df['radius_mean']>=13.37]
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38           122.8     1001.0
# 842517           M        20.57         17.77           132.9     1326.0
# 84300903         M        19.69         21.25           130.0     1203.0
# 84358402         M        20.29         14.34           135.1     1297.0
# 844359           M        18.25         19.98           119.6     1040.0
# ...            ...          ...           ...             ...        ...
# 926125           M        20.92         25.09           143.0     1347.0
# 926424           M        21.56         22.39           142.0     1479.0
# 926682           M        20.13         28.25           131.2     1261.0
# 926954           M        16.60         28.08           108.3      858.1
# 927241           M        20.60         29.33           140.1     1265.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# ...

# %%
df[df['radius_mean']<13.37].max()
# Out:
# diagnosis                                M
# radius_mean                          13.34
# texture_mean                         33.81
# perimeter_mean                        87.5
# area_mean                            551.7
# smoothness_mean                     0.1634
# compactness_mean                    0.2839
# concavity_mean                      0.4108
# concave points_mean                 0.1052
# symmetry_mean                       0.2743
# fractal_dimension_mean             0.09744
# radius_se                           0.8245
# texture_se                           4.885
# perimeter_se                         5.118
# area_se                              53.65
# smoothness_se                      0.02177
# compactness_se                     0.09586
# concavity_se                         0.396
# concave points_se                  0.05279
# symmetry_se                        0.06146
# fractal_dimension_se               0.02984
# radius_worst                         17.38
# ...

# %%
df.loc[(df['radius_mean']>=13.37), 'class_radius'] = 'H'

# %%
df.loc[(df['radius_mean']<13.37), 'class_radius'] = 'L'

# %%
df
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# ...            ...          ...           ...             ...        ...
# 926424           M        21.56         22.39          142.00     1479.0
# 926682           M        20.13         28.25          131.20     1261.0
# 926954           M        16.60         28.08          108.30      858.1
# 927241           M        20.60         29.33          140.10     1265.0
# 92751            B         7.76         24.54           47.92      181.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# ...

# %%
df.drop('class_radius', axis=1, inplace=True)

# %%
import numpy as np

# %%
cond = [(df['radius_mean']>=13.37), (df['radius_mean']<13.37)]
esc= ['H', 'L']
df['class_radius'] =np.select(cond, esc, default=None)

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.groupby('class_radius').mean()
# Out:
# /tmp/ipykernel_13973/3544085303.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('class_radius').mean()
#                         id  radius_mean  texture_mean  perimeter_mean  \
# class_radius
# H             3.132331e+07    16.787018     20.422561      110.243474
# L             2.941700e+07    11.458201     18.152746       73.630246
#
#                area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# class_radius
# H             900.769123         0.098084          0.125801        0.128469
# L             408.143310         0.094630          0.082805        0.048990
#
#               concave points_mean  symmetry_mean  ...  perimeter_worst  \
# class_radius                                      ...
# ...

# %%
df.groupby('class_radius').corr()
# Out:
# /tmp/ipykernel_13973/2401460140.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.corr is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('class_radius').corr()
#                                                    id  radius_mean  \
# class_radius
# H            id                              1.000000     0.168231
#              radius_mean                     0.168231     1.000000
#              texture_mean                    0.149999     0.271884
#              perimeter_mean                  0.165762     0.995504
#              area_mean                       0.190981     0.992442
# ...                                               ...          ...
# L            concave points_worst           -0.009349     0.331614
#              symmetry_worst                  0.020931     0.014830
# ...

# %%
df.groupby(['diagnosis','class_radius']).mean()
# Out:
#                         radius_mean  texture_mean  perimeter_mean  \
# diagnosis class_radius
# B         H               14.358778     17.639333       92.749111
#           L               11.400820     18.007603       73.129213
# M         H               17.907744     21.707128      118.317795
#           L               12.359412     20.432353       81.499412
#
#                           area_mean  smoothness_mean  compactness_mean  \
# diagnosis class_radius
# B         H              636.956667         0.089906          0.085835
#           L              404.082397         0.093344          0.078146
# M         H             1022.528718         0.101859          0.144247
#           L              471.923529         0.114822          0.155974
#
#                         concavity_mean  concave points_mean  symmetry_mean  \
# diagnosis class_radius
# B         H                   0.054203             0.034984       0.168430
# ...

# %%
import random

# %%
AGE = []
SEX = []

# %%
df.shape[0]
# Out:
# 569

# %%
random.seed(222)

# %%
for i in range(df.shape[0]):
    AGE.append(random.randint(20,75))
    SEX.append(random.choice(['H','F']))

# %%
ID =df['id'].sort_values().tolist()

# %%
df2 = pd.DataFrame(data={'id':ID, 'sex':SEX, 'age': AGE})
df2
# Out:
#             id sex  age
# 0         8670   H   69
# 1         8913   F   35
# 2         8915   H   39
# 3         9047   F   21
# 4        85715   F   34
# ..         ...  ..  ...
# 564  911157302   F   31
# 565  911296201   H   28
# 566  911296202   F   62
# 567  911320501   F   42
# 568  911320502   H   61
#
# [569 rows x 3 columns]

# %%
dfMerge= df.merge(df2,how='inner', on='id')

# %%
dfMerge
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df3 = dfMerge.iloc[:10,:]*0

# %%
pd.concat([dfMerge,df3], ignore_index=True)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 574         0                   0.00          0.00            0.00        0.0
# 575         0                   0.00          0.00            0.00        0.0
# 576         0                   0.00          0.00            0.00        0.0
# 577         0                   0.00          0.00            0.00        0.0
# 578         0                   0.00          0.00            0.00        0.0
#
# ...

# %%
dfMerge.pivot(index='id', columns='diagnosis',values='radius_mean').fillna(0)
# Out:
# diagnosis      B      M
# id
# 8670        0.00  15.46
# 8913       12.89   0.00
# 8915       14.96   0.00
# 9047       12.94   0.00
# 85715       0.00  13.17
# ...          ...    ...
# 911157302   0.00  21.10
# 911296201   0.00  17.08
# 911296202   0.00  27.42
# 911320501  11.60   0.00
# 911320502  13.17   0.00
#
# [569 rows x 2 columns]

# %%
dfMerge.pivot_table(index='sex', columns='diagnosis',values='radius_mean', aggfunc='count')
# Out:
# diagnosis    B    M
# sex
# F          187  108
# H          170  104

# %%
dfMerge.pivot_table(index='sex', columns='diagnosis',values='radius_mean', aggfunc='count').T['H'].plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='H'>

# %%
df.plot(x='radius_mean', y='texture_mean',figsize=(15,7),kind='scatter')
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='texture_mean'>

# %%
dfMerge.plot(kind='box', y=['texture_mean', 'radius_mean'])
# Out:
# <AxesSubplot: >

# %%
import seaborn as sns

# %%
sns.boxplot(data=dfMerge[['texture_mean', 'radius_mean']])
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(x='diagnosis',y='texture_mean', data=dfMerge)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='texture_mean'>

# %%
sns.swarmplot(x='diagnosis',y='texture_mean',data=dfMerge)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='texture_mean'>

# %%
sns.barplot(x='diagnosis',y='texture_mean', data=dfMerge)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='texture_mean'>

# %%
sns.catplot(x='diagnosis',y='texture_mean',  hue='sex',data=dfMerge)

# %%
sns.pointplot(x='diagnosis',y='texture_mean', hue='sex',data=dfMerge)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='texture_mean'>

# %%
sns.countplot(x='diagnosis', hue='sex',data=dfMerge)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='count'>

# %%
sns.scatterplot(x='radius_mean',y='texture_mean', hue='diagnosis',data=dfMerge)
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='texture_mean'>

# %%
sns.lmplot(x='radius_mean',y='texture_mean', hue='diagnosis',data=dfMerge)

# %%
cols= cols + ['compactness_mean','concavity_mean']

# %%
sns.pairplot(data=dfMerge[cols], kind='reg', corner=True, hue='diagnosis')

# %%
sns.violinplot(x='sex', y='texture_mean', data=dfMerge, inner='quartile')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='texture_mean'>

# %%
sns.boxenplot(x='diagnosis', y='texture_mean', hue='sex', data=dfMerge)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='texture_mean'>

# %%
a= dfMerge.groupby('diagnosis').corr()
sns.heatmap(data=a)
# Out:
# /tmp/ipykernel_13973/3528054204.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.corr is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a= dfMerge.groupby('diagnosis').corr()
# <AxesSubplot: ylabel='diagnosis-None'>

# %%
b= dfMerge.pivot(index='id', columns='diagnosis', values='radius_mean').fillna(0)

# %%
sns.heatmap(data=b)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='id'>

# %%
c= dfMerge.pivot_table(index='sex', columns='diagnosis', values='radius_mean')

# %%
sns.heatmap(data=c)
# Out:
# <AxesSubplot: xlabel='diagnosis', ylabel='sex'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [213], line 3
#       1 # Importing the library
#       2 import seaborn as sns
# ----> 3 from sunbird.categorical_encoding import frequency_encoding
#       5 # Load dataset
#       6 data = sns.load_dataset('flights')
#
# ModuleNotFoundError: No module named 'sunbird'
